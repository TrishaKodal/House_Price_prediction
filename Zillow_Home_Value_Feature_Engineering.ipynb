# %% [markdown]
# ### Feature Engineering:
#
# In the following cells, we will engineer / pre-process the variables of the House Price Dataset from Kaggle. We will engineer the variables so that we tackle:
#
# * Duplicate check
# * Missing values
# * Temporal variables
# * Selective transformation of incorrectly scaled values
# * Standarise the values of all variables to the same range (Standardization)
# * Encoding of Categorical variables
# * Forming new meaningful features if needed
# * Dropping redundant columns
# * Multi-Colinearity check and removal
# * Outlier check and removal

# %% [markdown]
# ### Import necessary libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math as mt
import matplotlib.pyplot as plt
import warnings
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline
pd.set_option('display.max_columns',None)
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Load Dataset:

# %%
df = pd.read_csv(r'C:\Users\TRISHA\Documents\Data_science\House_Price_prediction_final\zillow_initial_dataset.csv')
df_copy = df.copy()
df.shape
# Out:
# (90275, 60)

# %%
df.head(10)
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
# 5  17125829                    NaN                       NaN           NaN
# 6  17132911                    NaN                       NaN           NaN
# 7  17134926                    NaN                       NaN           NaN
# 8  17139988                    NaN                       NaN           NaN
# 9  17167359                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
# 5          2.5         4.0                  NaN                    NaN
# 6          2.0         3.0                  NaN                    NaN
# 7          2.5         5.0                  NaN                    NaN
# 8          2.0         3.0                  NaN                    NaN
# 9          1.0         3.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                2.5         NaN                     548.0
# 1                1.0         NaN                     777.0
# 2                2.0         NaN                    1101.0
# 3                1.5         NaN                    1554.0
# 4                2.5         NaN                    1305.0
# 5                2.5        66.0                    1303.0
# 6                2.0         NaN                    1772.0
# 7                2.5         NaN                    1240.0
# 8                2.0         NaN                    1292.0
# 9                1.0         NaN                     804.0
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                        1264.0                1264.0                   NaN
# 1                         777.0                 777.0                   NaN
# 2                        1101.0                1101.0                   NaN
# 3                        1554.0                1554.0                   NaN
# 4                        2415.0                2415.0                   NaN
# 5                        2882.0                2882.0                   NaN
# 6                        1772.0                1772.0                   NaN
# 7                        2632.0                2632.0                   NaN
# 8                        1292.0                1292.0                   NaN
# 9                        1385.0                1385.0                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6    fips  \
# 0                   NaN                 548.0                  NaN  6111.0
# 1                   NaN                 777.0                  NaN  6111.0
# 2                   NaN                1101.0                  NaN  6111.0
# 3                   NaN                1554.0                  NaN  6111.0
# 4                   NaN                1305.0                  NaN  6111.0
# 5                   NaN                1303.0                  NaN  6111.0
# 6                   NaN                1772.0                  NaN  6111.0
# 7                   NaN                1240.0                  NaN  6111.0
# 8                   NaN                1292.0                  NaN  6111.0
# 9                   NaN                 804.0                  NaN  6111.0
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          2.0           2.0              0.0            NaN
# 1           NaN          1.0           1.0              0.0            NaN
# 2           NaN          2.0           2.0            441.0            NaN
# 3           1.0          1.0           2.0            460.0            NaN
# 4           1.0          2.0           2.0            665.0            NaN
# 5           1.0          2.0           2.0            473.0            NaN
# 6           1.0          2.0           2.0            467.0            NaN
# 7           1.0          2.0           2.0            440.0            NaN
# 8           NaN          2.0           2.0            494.0            NaN
# 9           1.0          1.0           1.0            253.0            NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  34303597.0 -119287236.0             1735.0      NaN
# 1                    NaN  34272866.0 -119198911.0                NaN      NaN
# 2                    NaN  34340801.0 -119079610.0             6569.0      NaN
# 3                    NaN  34354313.0 -119076405.0             7400.0      NaN
# 4                    NaN  34266578.0 -119165392.0             6326.0      NaN
# 5                    NaN  34240014.0 -119024793.0            10000.0      NaN
# 6                    NaN  34226842.0 -119059815.0             8059.0      NaN
# 7                    NaN  34229816.0 -119050224.0             7602.0      1.0
# 8                    NaN  34226351.0 -118983853.0             7405.0      NaN
# 9                    NaN  34179289.0 -119169287.0             6000.0      NaN
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
# 5          NaN           NaN          NaN          NaN
# 6          NaN           NaN          NaN          NaN
# 7        800.0           NaN          NaN          1.0
# 8          NaN           NaN          NaN          NaN
# 9          NaN           NaN          NaN          NaN
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      1128                  265.0                NaN
# 1                      1129                  266.0                NaN
# 2                      1111                  261.0                NaN
# 3                      1110                  261.0                NaN
# 4                      1111                  261.0                NaN
# 5                      1111                  261.0                NaN
# 6                      1111                  261.0                NaN
# 7                      1111                  261.0                NaN
# 8                      1111                  261.0                NaN
# 9                      1111                  261.0                NaN
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.111002e+07       34543.0          2061.0                   NaN
# 1            6.111002e+07       34543.0          2061.0                   NaN
# 2            6.111001e+07       26965.0          2061.0                   NaN
# 3            6.111001e+07       26965.0          2061.0                   NaN
# 4            6.111001e+07       34543.0          2061.0                   NaN
# 5            6.111005e+07       51239.0          2061.0                   NaN
# 6            6.111006e+07       51239.0          2061.0                   NaN
# 7            6.111006e+07       51239.0          2061.0                   NaN
# 8            6.111005e+07       51239.0          2061.0                   NaN
# 9            6.111004e+07       13150.0          2061.0                   NaN
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      97081.0      5.0          NaN                  1.0
# 1      97083.0      4.0          NaN                  NaN
# 2      97113.0      5.0          NaN                  NaN
# 3      97113.0      5.0          NaN                  1.0
# 4      97084.0      8.0          NaN                  1.0
# 5      97089.0      8.0          NaN                  1.0
# 6      97089.0      6.0          NaN                  NaN
# 7      97089.0      8.0          NaN                  1.0
# 8      97091.0      6.0          NaN                  NaN
# 9      97104.0      6.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN               128.0                 NaN
# 1                     NaN      NaN               198.0                 NaN
# 2                     NaN      NaN                 NaN                 NaN
# 3                     NaN      NaN                 NaN                 NaN
# 4                     NaN      NaN                 NaN                 NaN
# 5                     NaN      NaN                 NaN                 NaN
# 6                     NaN      NaN              1045.0                 NaN
# 7                     NaN      NaN               180.0                 NaN
# 8                     NaN      NaN               304.0                 NaN
# 9                     NaN      NaN                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0     1986.0              2.0           NaN                    115087.0
# 1     1990.0              1.0           NaN                    143809.0
# 2     1956.0              1.0           NaN                     33619.0
# 3     1965.0              1.0           NaN                     45609.0
# 4     1984.0              2.0           NaN                    277000.0
# 5     1980.0              2.0           NaN                    222070.0
# 6     1978.0              1.0           NaN                    185000.0
# 7     1971.0              2.0           NaN                    342611.0
# 8     1979.0              1.0           NaN                    231297.0
# 9     1950.0              1.0           NaN                    134251.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0          2015.0                76724.0    2015.06
# 1           239679.0          2015.0                95870.0    2581.30
# 2            47853.0          2015.0                14234.0     591.64
# 3            62914.0          2015.0                17305.0     682.78
# 4           554000.0          2015.0               277000.0    5886.92
# 5           289609.0          2015.0                67539.0    3110.44
# 6           526000.0          2015.0               341000.0    5632.20
# 7           571086.0          2015.0               228475.0    6109.94
# 8           462594.0          2015.0               231297.0    5026.40
# 9           268502.0          2015.0               134251.0    3217.06
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                NaN                 NaN         6.111002e+13    0.0953
# 1                NaN                 NaN         6.111002e+13    0.0198
# 2                NaN                 NaN         6.111001e+13    0.0060
# 3                NaN                 NaN         6.111001e+13   -0.0566
# 4                NaN                 NaN         6.111001e+13    0.0573
# 5                NaN                 NaN         6.111005e+13    0.0564
# 6                NaN                 NaN         6.111006e+13    0.0315
# 7                NaN                 NaN         6.111006e+13    0.0257
# 8                NaN                 NaN         6.111005e+13    0.0020
# 9                NaN                 NaN         6.111004e+13   -0.0576
#
#   transactiondate
# 0      2016-01-27
# 1      2016-03-30
# 2      2016-05-27
# 3      2016-06-07
# 4      2016-08-08
# 5      2016-08-26
# 6      2016-07-08
# 7      2016-05-11
# 8      2016-06-15
# 9      2016-05-27

# %% [markdown]
# ### Duplicate entry check and removal:

# %%
duplicate = df[df.duplicated('parcelid')]
duplicate.shape
# Out:
# (125, 60)

# %% [markdown]
# We observe that there are 125 rows of duplicate data with respect to the same parcelid.
# Hence, we will go ahead and drop those.

# %%
df.drop_duplicates(subset ="parcelid", keep = 'first', inplace = True)
df.shape
# Out:
# (90150, 60)

# %% [markdown]
# ###  Missing Values:

# %%
mis_val = [var for var in df.columns if df[var].isnull().sum()>0]
df[mis_val].isnull().sum()
# Out:
# airconditioningtypeid           61402
# architecturalstyletypeid        89890
# basementsqft                    90107
# buildingclasstypeid             90134
# buildingqualitytypeid           32866
# calculatedbathnbr                1176
# decktypeid                      89492
# finishedfloor1squarefeet        83300
# calculatedfinishedsquarefeet      658
# finishedsquarefeet12             4665
# finishedsquarefeet13            90117
# finishedsquarefeet15            86595
# finishedsquarefeet50            83300
# finishedsquarefeet6             89731
# fireplacecnt                    80553
# fullbathcnt                      1176
# garagecarcnt                    60253
# garagetotalsqft                 60253
# hashottuborspa                  87787
# heatingorsystemtypeid           34145
# lotsizesquarefeet               10136
# poolcnt                         72274
# poolsizesum                     89184
# pooltypeid10                    88991
# pooltypeid2                     88946
# pooltypeid7                     73478
# propertycountylandusecode           1
# propertyzoningdesc              31918
# regionidcity                     1801
# regionidneighborhood            54194
# regionidzip                        35
# storytypeid                     90107
# threequarterbathnbr             78154
# typeconstructiontypeid          89852
# unitcnt                         31879
# yardbuildingsqft17              87505
# yardbuildingsqft26              90055
# yearbuilt                         753
# numberofstories                 69610
# fireplaceflag                   89930
# structuretaxvaluedollarcnt        378
# taxvaluedollarcnt                   1
# landtaxvaluedollarcnt               1
# taxamount                           6
# taxdelinquencyflag              88375
# taxdelinquencyyear              88375
# censustractandblock               603
# dtype: int64

# %% [markdown]
# We see plenty of missing value for multiple columns in the dataset.
# 1168 rows account for 100% of the data. So, in order to avoid generating synthetic data for columns which have more than 60% missing values, we will drop those columns and perform feature engineering on the rest of the data.

# %% [markdown]
# ### Dropping columns having >60% missing values:

# %%
df.shape
# Out:
# (90150, 60)

# %%
def drop_columns_with_max_missing_values(df):
    mis_var = [var for var in df.columns if df[var].isnull().sum() > 0]
    df[mis_var].isnull().sum()

    limit = np.abs((df.shape[0] * 0.6))
    var_to_be_dropped = [var for var in mis_var if df[var].isnull().sum() > limit]
    print('Columns with more than 60% missing values: \n\n', var_to_be_dropped)
    print('\n##### Dropping columns with more than 60% missing values #####\n')

    df.drop(columns=var_to_be_dropped, axis=1, inplace=True)
    print('Remaining columns: \n', df.columns)
    return df

df = drop_columns_with_max_missing_values(df)
# Out:
# Columns with more than 60% missing values:
#
#  ['airconditioningtypeid', 'architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedfloor1squarefeet', 'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50', 'finishedsquarefeet6', 'fireplacecnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'regionidneighborhood', 'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid', 'yardbuildingsqft17', 'yardbuildingsqft26', 'numberofstories', 'fireplaceflag', 'taxdelinquencyflag', 'taxdelinquencyyear']
#
# ##### Dropping columns with more than 60% missing values #####
#
# Remaining columns:
#  Index(['parcelid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'fips', 'fullbathcnt', 'heatingorsystemtypeid',
#        'latitude', 'longitude', 'lotsizesquarefeet',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidzip', 'roomcnt', 'unitcnt', 'yearbuilt',
#        'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear',
#        'landtaxvaluedollarcnt', 'taxamount', 'censustractandblock', 'logerror',
#        'transactiondate'],
#       dtype='object')

# %%
df.shape
# Out:
# (90150, 31)

# %%
df.head(10)
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
# 5  17125829          2.5         4.0                    NaN
# 6  17132911          2.0         3.0                    NaN
# 7  17134926          2.5         5.0                    NaN
# 8  17139988          2.0         3.0                    NaN
# 9  17167359          1.0         3.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
# 5                2.5                        2882.0                2882.0
# 6                2.0                        1772.0                1772.0
# 7                2.5                        2632.0                2632.0
# 8                2.0                        1292.0                1292.0
# 9                1.0                        1385.0                1385.0
#
#      fips  fullbathcnt  heatingorsystemtypeid    latitude    longitude  \
# 0  6111.0          2.0                    NaN  34303597.0 -119287236.0
# 1  6111.0          1.0                    NaN  34272866.0 -119198911.0
# 2  6111.0          2.0                    NaN  34340801.0 -119079610.0
# 3  6111.0          1.0                    NaN  34354313.0 -119076405.0
# 4  6111.0          2.0                    NaN  34266578.0 -119165392.0
# 5  6111.0          2.0                    NaN  34240014.0 -119024793.0
# 6  6111.0          2.0                    NaN  34226842.0 -119059815.0
# 7  6111.0          2.0                    NaN  34229816.0 -119050224.0
# 8  6111.0          2.0                    NaN  34226351.0 -118983853.0
# 9  6111.0          1.0                    NaN  34179289.0 -119169287.0
#
#    lotsizesquarefeet propertycountylandusecode  propertylandusetypeid  \
# 0             1735.0                      1128                  265.0
# 1                NaN                      1129                  266.0
# 2             6569.0                      1111                  261.0
# 3             7400.0                      1110                  261.0
# 4             6326.0                      1111                  261.0
# 5            10000.0                      1111                  261.0
# 6             8059.0                      1111                  261.0
# 7             7602.0                      1111                  261.0
# 8             7405.0                      1111                  261.0
# 9             6000.0                      1111                  261.0
#
#   propertyzoningdesc  rawcensustractandblock  regionidcity  regionidcounty  \
# 0                NaN            6.111002e+07       34543.0          2061.0
# 1                NaN            6.111002e+07       34543.0          2061.0
# 2                NaN            6.111001e+07       26965.0          2061.0
# 3                NaN            6.111001e+07       26965.0          2061.0
# 4                NaN            6.111001e+07       34543.0          2061.0
# 5                NaN            6.111005e+07       51239.0          2061.0
# 6                NaN            6.111006e+07       51239.0          2061.0
# 7                NaN            6.111006e+07       51239.0          2061.0
# 8                NaN            6.111005e+07       51239.0          2061.0
# 9                NaN            6.111004e+07       13150.0          2061.0
#
#    regionidzip  roomcnt  unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
# 0      97081.0      5.0      NaN     1986.0                    115087.0
# 1      97083.0      4.0      NaN     1990.0                    143809.0
# 2      97113.0      5.0      NaN     1956.0                     33619.0
# 3      97113.0      5.0      NaN     1965.0                     45609.0
# 4      97084.0      8.0      NaN     1984.0                    277000.0
# 5      97089.0      8.0      NaN     1980.0                    222070.0
# 6      97089.0      6.0      NaN     1978.0                    185000.0
# 7      97089.0      8.0      NaN     1971.0                    342611.0
# 8      97091.0      6.0      NaN     1979.0                    231297.0
# 9      97104.0      6.0      NaN     1950.0                    134251.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0          2015.0                76724.0    2015.06
# 1           239679.0          2015.0                95870.0    2581.30
# 2            47853.0          2015.0                14234.0     591.64
# 3            62914.0          2015.0                17305.0     682.78
# 4           554000.0          2015.0               277000.0    5886.92
# 5           289609.0          2015.0                67539.0    3110.44
# 6           526000.0          2015.0               341000.0    5632.20
# 7           571086.0          2015.0               228475.0    6109.94
# 8           462594.0          2015.0               231297.0    5026.40
# 9           268502.0          2015.0               134251.0    3217.06
#
#    censustractandblock  logerror transactiondate
# 0         6.111002e+13    0.0953      2016-01-27
# 1         6.111002e+13    0.0198      2016-03-30
# 2         6.111001e+13    0.0060      2016-05-27
# 3         6.111001e+13   -0.0566      2016-06-07
# 4         6.111001e+13    0.0573      2016-08-08
# 5         6.111005e+13    0.0564      2016-08-26
# 6         6.111006e+13    0.0315      2016-07-08
# 7         6.111006e+13    0.0257      2016-05-11
# 8         6.111005e+13    0.0020      2016-06-15
# 9         6.111004e+13   -0.0576      2016-05-27

# %% [markdown]
# ### Capture elapsed time:

# %%
df['yeardifference'] = df['assessmentyear'] - df['yearbuilt']
df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#      fips  fullbathcnt  heatingorsystemtypeid    latitude    longitude  \
# 0  6111.0          2.0                    NaN  34303597.0 -119287236.0
# 1  6111.0          1.0                    NaN  34272866.0 -119198911.0
# 2  6111.0          2.0                    NaN  34340801.0 -119079610.0
# 3  6111.0          1.0                    NaN  34354313.0 -119076405.0
# 4  6111.0          2.0                    NaN  34266578.0 -119165392.0
#
#    lotsizesquarefeet propertycountylandusecode  propertylandusetypeid  \
# 0             1735.0                      1128                  265.0
# 1                NaN                      1129                  266.0
# 2             6569.0                      1111                  261.0
# 3             7400.0                      1110                  261.0
# 4             6326.0                      1111                  261.0
#
#   propertyzoningdesc  rawcensustractandblock  regionidcity  regionidcounty  \
# 0                NaN            6.111002e+07       34543.0          2061.0
# 1                NaN            6.111002e+07       34543.0          2061.0
# 2                NaN            6.111001e+07       26965.0          2061.0
# 3                NaN            6.111001e+07       26965.0          2061.0
# 4                NaN            6.111001e+07       34543.0          2061.0
#
#    regionidzip  roomcnt  unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
# 0      97081.0      5.0      NaN     1986.0                    115087.0
# 1      97083.0      4.0      NaN     1990.0                    143809.0
# 2      97113.0      5.0      NaN     1956.0                     33619.0
# 3      97113.0      5.0      NaN     1965.0                     45609.0
# 4      97084.0      8.0      NaN     1984.0                    277000.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0          2015.0                76724.0    2015.06
# 1           239679.0          2015.0                95870.0    2581.30
# 2            47853.0          2015.0                14234.0     591.64
# 3            62914.0          2015.0                17305.0     682.78
# 4           554000.0          2015.0               277000.0    5886.92
#
#    censustractandblock  logerror transactiondate  yeardifference
# 0         6.111002e+13    0.0953      2016-01-27            29.0
# 1         6.111002e+13    0.0198      2016-03-30            25.0
# 2         6.111001e+13    0.0060      2016-05-27            59.0
# 3         6.111001e+13   -0.0566      2016-06-07            50.0
# 4         6.111001e+13    0.0573      2016-08-08            31.0

# %%
df.drop(columns=['assessmentyear', 'yearbuilt', 'transactiondate'], axis=1, inplace=True)

# %% [markdown]
# ### Transform incorrectly scaled variables:

# %% [markdown]
# As mentioned in the data dictionary, the latitude and longitude has been multiplied to 10^6.
# So we will perform a division of the same to scale it to original.
# We will perform a similar operation for 'rawcensustractandblock'.
# Also, we will perform a division of 10^12 for the 'censustractandblock' variable to bring it to original scale.

# %%
df[['latitude', 'longitude']] = (df[['latitude', 'longitude']])/(10**6)
df['censustractandblock'] = (df['censustractandblock'])/(10**12)
df['rawcensustractandblock'] = (df['rawcensustractandblock'])/(10**6)
df.head(10)
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
# 5  17125829          2.5         4.0                    NaN
# 6  17132911          2.0         3.0                    NaN
# 7  17134926          2.5         5.0                    NaN
# 8  17139988          2.0         3.0                    NaN
# 9  17167359          1.0         3.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
# 5                2.5                        2882.0                2882.0
# 6                2.0                        1772.0                1772.0
# 7                2.5                        2632.0                2632.0
# 8                2.0                        1292.0                1292.0
# 9                1.0                        1385.0                1385.0
#
#      fips  fullbathcnt  heatingorsystemtypeid   latitude   longitude  \
# 0  6111.0          2.0                    NaN  34.303597 -119.287236
# 1  6111.0          1.0                    NaN  34.272866 -119.198911
# 2  6111.0          2.0                    NaN  34.340801 -119.079610
# 3  6111.0          1.0                    NaN  34.354313 -119.076405
# 4  6111.0          2.0                    NaN  34.266578 -119.165392
# 5  6111.0          2.0                    NaN  34.240014 -119.024793
# 6  6111.0          2.0                    NaN  34.226842 -119.059815
# 7  6111.0          2.0                    NaN  34.229816 -119.050224
# 8  6111.0          2.0                    NaN  34.226351 -118.983853
# 9  6111.0          1.0                    NaN  34.179289 -119.169287
#
#    lotsizesquarefeet propertycountylandusecode  propertylandusetypeid  \
# 0             1735.0                      1128                  265.0
# 1                NaN                      1129                  266.0
# 2             6569.0                      1111                  261.0
# 3             7400.0                      1110                  261.0
# 4             6326.0                      1111                  261.0
# 5            10000.0                      1111                  261.0
# 6             8059.0                      1111                  261.0
# 7             7602.0                      1111                  261.0
# 8             7405.0                      1111                  261.0
# 9             6000.0                      1111                  261.0
#
#   propertyzoningdesc  rawcensustractandblock  regionidcity  regionidcounty  \
# 0                NaN               61.110022       34543.0          2061.0
# 1                NaN               61.110015       34543.0          2061.0
# 2                NaN               61.110007       26965.0          2061.0
# 3                NaN               61.110008       26965.0          2061.0
# 4                NaN               61.110014       34543.0          2061.0
# 5                NaN               61.110052       51239.0          2061.0
# 6                NaN               61.110055       51239.0          2061.0
# 7                NaN               61.110055       51239.0          2061.0
# 8                NaN               61.110053       51239.0          2061.0
# 9                NaN               61.110039       13150.0          2061.0
#
#    regionidzip  roomcnt  unitcnt  structuretaxvaluedollarcnt  \
# 0      97081.0      5.0      NaN                    115087.0
# 1      97083.0      4.0      NaN                    143809.0
# 2      97113.0      5.0      NaN                     33619.0
# 3      97113.0      5.0      NaN                     45609.0
# 4      97084.0      8.0      NaN                    277000.0
# 5      97089.0      8.0      NaN                    222070.0
# 6      97089.0      6.0      NaN                    185000.0
# 7      97089.0      8.0      NaN                    342611.0
# 8      97091.0      6.0      NaN                    231297.0
# 9      97104.0      6.0      NaN                    134251.0
#
#    taxvaluedollarcnt  landtaxvaluedollarcnt  taxamount  censustractandblock  \
# 0           191811.0                76724.0    2015.06            61.110022
# 1           239679.0                95870.0    2581.30            61.110015
# 2            47853.0                14234.0     591.64            61.110007
# 3            62914.0                17305.0     682.78            61.110008
# 4           554000.0               277000.0    5886.92            61.110014
# 5           289609.0                67539.0    3110.44            61.110052
# 6           526000.0               341000.0    5632.20            61.110055
# 7           571086.0               228475.0    6109.94            61.110055
# 8           462594.0               231297.0    5026.40            61.110053
# 9           268502.0               134251.0    3217.06            61.110039
#
#    logerror  yeardifference
# 0    0.0953            29.0
# 1    0.0198            25.0
# 2    0.0060            59.0
# 3   -0.0566            50.0
# 4    0.0573            31.0
# 5    0.0564            35.0
# 6    0.0315            37.0
# 7    0.0257            44.0
# 8    0.0020            36.0
# 9   -0.0576            65.0

# %%
df.shape
# Out:
# (90150, 29)

# %% [markdown]
# ### Handling missing values:
# To deal with missing values in numerical variables, we will:
#
# * Replace the missing values in the original variable with the mode

# %%
df.isnull().sum()
# Out:
# parcelid                            0
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           32866
# calculatedbathnbr                1176
# calculatedfinishedsquarefeet      658
# finishedsquarefeet12             4665
# fips                                0
# fullbathcnt                      1176
# heatingorsystemtypeid           34145
# latitude                            0
# longitude                           0
# lotsizesquarefeet               10136
# propertycountylandusecode           1
# propertylandusetypeid               0
# propertyzoningdesc              31918
# rawcensustractandblock              0
# regionidcity                     1801
# regionidcounty                      0
# regionidzip                        35
# roomcnt                             0
# unitcnt                         31879
# structuretaxvaluedollarcnt        378
# taxvaluedollarcnt                   1
# landtaxvaluedollarcnt               1
# taxamount                           6
# censustractandblock               603
# logerror                            0
# yeardifference                    753
# dtype: int64

# %%
def replace_missing_data(df, mis_vars):
    print('##### Replacing missing values with mode of features #####')
    for var in mis_vars:
        df[var] = df[var].fillna(df[var].mode()[0])
    return df

mis_var = [var for var in df.columns if df[var].isnull().sum() > 0]
df = replace_missing_data(df, mis_var)
# Out:
# ##### Replacing missing values with mode of features #####

# %%
df.isnull().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# finishedsquarefeet12            0
# fips                            0
# fullbathcnt                     0
# heatingorsystemtypeid           0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# propertylandusetypeid           0
# propertyzoningdesc              0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# unitcnt                         0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# logerror                        0
# yeardifference                  0
# dtype: int64

# %% [markdown]
# ### Encoding categorical variables:

# %%
cat_vars = [var for var in df.columns if df[var].dtypes=='O']
cat_vars
# Out:
# ['propertycountylandusecode', 'propertyzoningdesc']

# %%
def encode_categorical_variables(df, cat_vars):
    print('##### Performing Label Encoding on Categorical Variables #####')
    print('Categorical variables: ', cat_vars)
    for i in range(len(cat_vars)):
        var = cat_vars[i]
        var_le = LabelEncoder()
        var_labels = var_le.fit_transform(df[var])
        var_mappings = {index: label for index, label in enumerate(var_le.classes_)}
        df[(var + '_labels')] = var_labels
        df.drop(columns=var, axis=1, inplace=True)
    return df

df = encode_categorical_variables(df, cat_vars)
# Out:
# ##### Performing Label Encoding on Categorical Variables #####
# Categorical variables:  ['propertycountylandusecode', 'propertyzoningdesc']

# %%
df.head(10)
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    7.0
# 1  17088994          1.0         2.0                    7.0
# 2  17100444          2.0         3.0                    7.0
# 3  17102429          1.5         2.0                    7.0
# 4  17109604          2.5         4.0                    7.0
# 5  17125829          2.5         4.0                    7.0
# 6  17132911          2.0         3.0                    7.0
# 7  17134926          2.5         5.0                    7.0
# 8  17139988          2.0         3.0                    7.0
# 9  17167359          1.0         3.0                    7.0
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
# 5                2.5                        2882.0                2882.0
# 6                2.0                        1772.0                1772.0
# 7                2.5                        2632.0                2632.0
# 8                2.0                        1292.0                1292.0
# 9                1.0                        1385.0                1385.0
#
#      fips  fullbathcnt  heatingorsystemtypeid   latitude   longitude  \
# 0  6111.0          2.0                    2.0  34.303597 -119.287236
# 1  6111.0          1.0                    2.0  34.272866 -119.198911
# 2  6111.0          2.0                    2.0  34.340801 -119.079610
# 3  6111.0          1.0                    2.0  34.354313 -119.076405
# 4  6111.0          2.0                    2.0  34.266578 -119.165392
# 5  6111.0          2.0                    2.0  34.240014 -119.024793
# 6  6111.0          2.0                    2.0  34.226842 -119.059815
# 7  6111.0          2.0                    2.0  34.229816 -119.050224
# 8  6111.0          2.0                    2.0  34.226351 -118.983853
# 9  6111.0          1.0                    2.0  34.179289 -119.169287
#
#    lotsizesquarefeet  propertylandusetypeid  rawcensustractandblock  \
# 0             1735.0                  265.0               61.110022
# 1             6000.0                  266.0               61.110015
# 2             6569.0                  261.0               61.110007
# 3             7400.0                  261.0               61.110008
# 4             6326.0                  261.0               61.110014
# 5            10000.0                  261.0               61.110052
# 6             8059.0                  261.0               61.110055
# 7             7602.0                  261.0               61.110055
# 8             7405.0                  261.0               61.110053
# 9             6000.0                  261.0               61.110039
#
#    regionidcity  regionidcounty  regionidzip  roomcnt  unitcnt  \
# 0       34543.0          2061.0      97081.0      5.0      1.0
# 1       34543.0          2061.0      97083.0      4.0      1.0
# 2       26965.0          2061.0      97113.0      5.0      1.0
# 3       26965.0          2061.0      97113.0      5.0      1.0
# 4       34543.0          2061.0      97084.0      8.0      1.0
# 5       51239.0          2061.0      97089.0      8.0      1.0
# 6       51239.0          2061.0      97089.0      6.0      1.0
# 7       51239.0          2061.0      97089.0      8.0      1.0
# 8       51239.0          2061.0      97091.0      6.0      1.0
# 9       13150.0          2061.0      97104.0      6.0      1.0
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 0                    115087.0           191811.0                76724.0
# 1                    143809.0           239679.0                95870.0
# 2                     33619.0            47853.0                14234.0
# 3                     45609.0            62914.0                17305.0
# 4                    277000.0           554000.0               277000.0
# 5                    222070.0           289609.0                67539.0
# 6                    185000.0           526000.0               341000.0
# 7                    342611.0           571086.0               228475.0
# 8                    231297.0           462594.0               231297.0
# 9                    134251.0           268502.0               134251.0
#
#    taxamount  censustractandblock  logerror  yeardifference  \
# 0    2015.06            61.110022    0.0953            29.0
# 1    2581.30            61.110015    0.0198            25.0
# 2     591.64            61.110007    0.0060            59.0
# 3     682.78            61.110008   -0.0566            50.0
# 4    5886.92            61.110014    0.0573            31.0
# 5    3110.44            61.110052    0.0564            35.0
# 6    5632.20            61.110055    0.0315            37.0
# 7    6109.94            61.110055    0.0257            44.0
# 8    5026.40            61.110053    0.0020            36.0
# 9    3217.06            61.110039   -0.0576            65.0
#
#    propertycountylandusecode_labels  propertyzoningdesc_labels
# 0                                54                        609
# 1                                55                        609
# 2                                50                        609
# 3                                49                        609
# 4                                50                        609
# 5                                50                        609
# 6                                50                        609
# 7                                50                        609
# 8                                50                        609
# 9                                50                        609

# %% [markdown]
# ### Checking & Removing Outliers:

# %%
df.shape
# Out:
# (90150, 29)

# %%
z = np.abs(stats.zscore(df))
no_out_df = df[(z<3).all(axis=1)]
no_out_df.shape
# Out:
# (70260, 29)

# %% [markdown]
# ### Checking for Multi-Colinearity:

# %%
no_out_df.corr()
# Out:
#                                   parcelid  bathroomcnt  bedroomcnt  \
# parcelid                          1.000000     0.028423    0.014068
# bathroomcnt                       0.028423     1.000000    0.576233
# bedroomcnt                        0.014068     0.576233    1.000000
# buildingqualitytypeid             0.427057    -0.302725   -0.093848
# calculatedbathnbr                 0.032116     0.977620    0.536776
# calculatedfinishedsquarefeet      0.046356     0.723948    0.658793
# finishedsquarefeet12              0.050844     0.717572    0.646947
# fips                              0.875261     0.096319    0.062177
# fullbathcnt                      -0.071773     0.954987    0.528829
# heatingorsystemtypeid            -0.197104    -0.421220   -0.146429
# latitude                         -0.799259     0.025654    0.067254
# longitude                         0.870357     0.033585    0.055389
# lotsizesquarefeet                -0.206629     0.022510   -0.182343
# propertylandusetypeid             0.045825     0.016769   -0.383565
# rawcensustractandblock            0.875924     0.097628    0.064273
# regionidcity                      0.172686    -0.024891   -0.016572
# regionidcounty                   -0.875261    -0.096319   -0.062177
# regionidzip                       0.515522     0.160784    0.154325
# roomcnt                           0.515036     0.040256    0.198038
# unitcnt                          -0.032935     0.071092    0.091626
# structuretaxvaluedollarcnt        0.020601     0.585840    0.306879
# taxvaluedollarcnt                 0.108378     0.409102    0.228897
# landtaxvaluedollarcnt             0.131451     0.239859    0.142587
# taxamount                         0.036577     0.387460    0.230341
# censustractandblock               0.870684     0.099102    0.067906
# logerror                          0.025329     0.045766    0.035055
# yeardifference                   -0.222907    -0.455964   -0.075797
# propertycountylandusecode_labels  0.852989     0.093602    0.006568
# propertyzoningdesc_labels        -0.212511     0.018170    0.042841
#
#                                   buildingqualitytypeid  calculatedbathnbr  \
# parcelid                                       0.427057           0.032116
# bathroomcnt                                   -0.302725           0.977620
# bedroomcnt                                    -0.093848           0.536776
# buildingqualitytypeid                          1.000000          -0.299723
# calculatedbathnbr                             -0.299723           1.000000
# calculatedfinishedsquarefeet                  -0.205977           0.734344
# finishedsquarefeet12                          -0.213388           0.725233
# fips                                           0.421916           0.102517
# fullbathcnt                                   -0.352713           0.978121
# heatingorsystemtypeid                          0.276822          -0.441510
# latitude                                      -0.401890           0.027565
# longitude                                      0.365455           0.037354
# lotsizesquarefeet                             -0.232023           0.019215
# propertylandusetypeid                         -0.205658           0.020252
# rawcensustractandblock                         0.420252           0.103956
# regionidcity                                   0.048790          -0.025117
# regionidcounty                                -0.421916          -0.102517
# regionidzip                                    0.194921           0.171171
# roomcnt                                        0.275909           0.033440
# unitcnt                                        0.049354           0.085811
# structuretaxvaluedollarcnt                    -0.190432           0.602654
# taxvaluedollarcnt                             -0.055208           0.416746
# landtaxvaluedollarcnt                          0.024085           0.245013
# taxamount                                     -0.082563           0.401416
# censustractandblock                            0.417279           0.103023
# logerror                                      -0.007708           0.043166
# yeardifference                                 0.230517          -0.458126
# propertycountylandusecode_labels               0.387709           0.102588
# propertyzoningdesc_labels                     -0.191120           0.016810
#
#                                   calculatedfinishedsquarefeet  \
# parcelid                                              0.046356
# bathroomcnt                                           0.723948
# bedroomcnt                                            0.658793
# buildingqualitytypeid                                -0.205977
# calculatedbathnbr                                     0.734344
# calculatedfinishedsquarefeet                          1.000000
# finishedsquarefeet12                                  0.987221
# fips                                                  0.123846
# fullbathcnt                                           0.709037
# heatingorsystemtypeid                                -0.303495
# latitude                                              0.009003
# longitude                                             0.064941
# lotsizesquarefeet                                    -0.120061
# propertylandusetypeid                                -0.260786
# rawcensustractandblock                                0.125167
# regionidcity                                         -0.045079
# regionidcounty                                       -0.123846
# regionidzip                                           0.182274
# roomcnt                                               0.123370
# unitcnt                                               0.084267
# structuretaxvaluedollarcnt                            0.670533
# taxvaluedollarcnt                                     0.507249
# landtaxvaluedollarcnt                                 0.329372
# taxamount                                             0.502419
# censustractandblock                                   0.125288
# logerror                                              0.050139
# yeardifference                                       -0.250244
# propertycountylandusecode_labels                      0.076094
# propertyzoningdesc_labels                            -0.000506
#
#                                   finishedsquarefeet12      fips  fullbathcnt  \
# parcelid                                      0.050844  0.875261    -0.071773
# bathroomcnt                                   0.717572  0.096319     0.954987
# bedroomcnt                                    0.646947  0.062177     0.528829
# buildingqualitytypeid                        -0.213388  0.421916    -0.352713
# calculatedbathnbr                             0.725233  0.102517     0.978121
# calculatedfinishedsquarefeet                  0.987221  0.123846     0.709037
# finishedsquarefeet12                          1.000000  0.130418     0.698733
# fips                                          0.130418  1.000000    -0.011524
# fullbathcnt                                   0.698733 -0.011524     1.000000
# heatingorsystemtypeid                        -0.299525 -0.294910    -0.413791
# latitude                                      0.008483 -0.683274     0.110533
# longitude                                     0.069499  0.705664    -0.049075
# lotsizesquarefeet                            -0.117778 -0.201421     0.043562
# propertylandusetypeid                        -0.199295  0.019266     0.009436
# rawcensustractandblock                        0.131834  0.999777    -0.010022
# regionidcity                                 -0.043502  0.053290    -0.036352
# regionidcounty                               -0.130418 -1.000000     0.011524
# regionidzip                                   0.192094  0.667727     0.095528
# roomcnt                                       0.128849  0.653662    -0.014656
# unitcnt                                      -0.051075 -0.043558     0.093458
# structuretaxvaluedollarcnt                    0.672593  0.064417     0.574096
# taxvaluedollarcnt                             0.507636  0.146449     0.385969
# landtaxvaluedollarcnt                         0.328845  0.159506     0.218985
# taxamount                                     0.501731  0.074968     0.379323
# censustractandblock                           0.131922  0.994001    -0.010311
# logerror                                      0.050546  0.019448     0.040571
# yeardifference                               -0.265281 -0.289936    -0.405678
# propertycountylandusecode_labels              0.070824  0.971803    -0.006417
# propertyzoningdesc_labels                     0.000853 -0.316782     0.053636
#
#                                   heatingorsystemtypeid  latitude  longitude  \
# parcelid                                      -0.197104 -0.799259   0.870357
# bathroomcnt                                   -0.421220  0.025654   0.033585
# bedroomcnt                                    -0.146429  0.067254   0.055389
# buildingqualitytypeid                          0.276822 -0.401890   0.365455
# calculatedbathnbr                             -0.441510  0.027565   0.037354
# calculatedfinishedsquarefeet                  -0.303495  0.009003   0.064941
# finishedsquarefeet12                          -0.299525  0.008483   0.069499
# fips                                          -0.294910 -0.683274   0.705664
# fullbathcnt                                   -0.413791  0.110533  -0.049075
# heatingorsystemtypeid                          1.000000  0.045993  -0.167438
# latitude                                       0.045993  1.000000  -0.587784
# longitude                                     -0.167438 -0.587784   1.000000
# lotsizesquarefeet                             -0.118462  0.165482  -0.205741
# propertylandusetypeid                         -0.202664 -0.047268  -0.029081
# rawcensustractandblock                        -0.296795 -0.678967   0.707549
# regionidcity                                   0.016368 -0.163661   0.134743
# regionidcounty                                 0.294910  0.683274  -0.705664
# regionidzip                                   -0.330675 -0.120092   0.613885
# roomcnt                                       -0.167427 -0.397168   0.392853
# unitcnt                                       -0.042316  0.004017  -0.032388
# structuretaxvaluedollarcnt                    -0.291480 -0.027756   0.011174
# taxvaluedollarcnt                             -0.175315 -0.196797   0.025089
# landtaxvaluedollarcnt                         -0.084778 -0.243788   0.026865
# taxamount                                     -0.140855 -0.119134  -0.034565
# censustractandblock                           -0.295272 -0.674860   0.703416
# logerror                                      -0.013840 -0.019062   0.022824
# yeardifference                                 0.518832  0.037249  -0.229471
# propertycountylandusecode_labels              -0.326597 -0.670985   0.675103
# propertyzoningdesc_labels                      0.023738  0.288372  -0.127404
#
#                                   lotsizesquarefeet  propertylandusetypeid  \
# parcelid                                  -0.206629               0.045825
# bathroomcnt                                0.022510               0.016769
# bedroomcnt                                -0.182343              -0.383565
# buildingqualitytypeid                     -0.232023              -0.205658
# calculatedbathnbr                          0.019215               0.020252
# calculatedfinishedsquarefeet              -0.120061              -0.260786
# finishedsquarefeet12                      -0.117778              -0.199295
# fips                                      -0.201421               0.019266
# fullbathcnt                                0.043562               0.009436
# heatingorsystemtypeid                     -0.118462              -0.202664
# latitude                                   0.165482              -0.047268
# longitude                                 -0.205741              -0.029081
# lotsizesquarefeet                          1.000000               0.349924
# propertylandusetypeid                      0.349924               1.000000
# rawcensustractandblock                    -0.201436               0.019586
# regionidcity                              -0.018692               0.056230
# regionidcounty                             0.201421              -0.019266
# regionidzip                               -0.133459              -0.018197
# roomcnt                                   -0.125968              -0.201244
# unitcnt                                   -0.023714              -0.458830
# structuretaxvaluedollarcnt                 0.012100               0.059079
# taxvaluedollarcnt                         -0.076301              -0.045769
# landtaxvaluedollarcnt                     -0.106996              -0.088475
# taxamount                                 -0.083357              -0.071128
# censustractandblock                       -0.200515               0.016865
# logerror                                  -0.001955               0.002084
# yeardifference                            -0.155921              -0.452982
# propertycountylandusecode_labels          -0.142743               0.092383
# propertyzoningdesc_labels                  0.061937               0.016864
#
#                                   rawcensustractandblock  regionidcity  \
# parcelid                                        0.875924      0.172686
# bathroomcnt                                     0.097628     -0.024891
# bedroomcnt                                      0.064273     -0.016572
# buildingqualitytypeid                           0.420252      0.048790
# calculatedbathnbr                               0.103956     -0.025117
# calculatedfinishedsquarefeet                    0.125167     -0.045079
# finishedsquarefeet12                            0.131834     -0.043502
# fips                                            0.999777      0.053290
# fullbathcnt                                    -0.010022     -0.036352
# heatingorsystemtypeid                          -0.296795      0.016368
# latitude                                       -0.678967     -0.163661
# longitude                                       0.707549      0.134743
# lotsizesquarefeet                              -0.201436     -0.018692
# propertylandusetypeid                           0.019586      0.056230
# rawcensustractandblock                          1.000000      0.060282
# regionidcity                                    0.060282      1.000000
# regionidcounty                                 -0.999777     -0.053290
# regionidzip                                     0.674030     -0.000995
# roomcnt                                         0.653732      0.003364
# unitcnt                                        -0.044166     -0.013087
# structuretaxvaluedollarcnt                      0.064843     -0.015272
# taxvaluedollarcnt                               0.144638      0.013521
# landtaxvaluedollarcnt                           0.156924      0.025387
# taxamount                                       0.073818      0.015491
# censustractandblock                             0.994221      0.058025
# logerror                                        0.019377      0.010770
# yeardifference                                 -0.295039     -0.037166
# propertycountylandusecode_labels                0.971456      0.042128
# propertyzoningdesc_labels                      -0.307880      0.190900
#
#                                   regionidcounty  regionidzip   roomcnt  \
# parcelid                               -0.875261     0.515522  0.515036
# bathroomcnt                            -0.096319     0.160784  0.040256
# bedroomcnt                             -0.062177     0.154325  0.198038
# buildingqualitytypeid                  -0.421916     0.194921  0.275909
# calculatedbathnbr                      -0.102517     0.171171  0.033440
# calculatedfinishedsquarefeet           -0.123846     0.182274  0.123370
# finishedsquarefeet12                   -0.130418     0.192094  0.128849
# fips                                   -1.000000     0.667727  0.653662
# fullbathcnt                             0.011524     0.095528 -0.014656
# heatingorsystemtypeid                   0.294910    -0.330675 -0.167427
# latitude                                0.683274    -0.120092 -0.397168
# longitude                              -0.705664     0.613885  0.392853
# lotsizesquarefeet                       0.201421    -0.133459 -0.125968
# propertylandusetypeid                  -0.019266    -0.018197 -0.201244
# rawcensustractandblock                 -0.999777     0.674030  0.653732
# regionidcity                           -0.053290    -0.000995  0.003364
# regionidcounty                          1.000000    -0.667727 -0.653662
# regionidzip                            -0.667727     1.000000  0.415072
# roomcnt                                -0.653662     0.415072  1.000000
# unitcnt                                 0.043558    -0.064279 -0.034781
# structuretaxvaluedollarcnt             -0.064417     0.063965 -0.123583
# taxvaluedollarcnt                      -0.146449    -0.007683  0.024996
# landtaxvaluedollarcnt                  -0.159506    -0.042267  0.094461
# taxamount                              -0.074968    -0.042265 -0.029549
# censustractandblock                    -0.994001     0.670147  0.656379
# logerror                               -0.019448     0.016003  0.015922
# yeardifference                          0.289936    -0.418668  0.020642
# propertycountylandusecode_labels       -0.971803     0.638416  0.623074
# propertyzoningdesc_labels               0.316782    -0.093470 -0.207093
#
#                                    unitcnt  structuretaxvaluedollarcnt  \
# parcelid                         -0.032935                    0.020601
# bathroomcnt                       0.071092                    0.585840
# bedroomcnt                        0.091626                    0.306879
# buildingqualitytypeid             0.049354                   -0.190432
# calculatedbathnbr                 0.085811                    0.602654
# calculatedfinishedsquarefeet      0.084267                    0.670533
# finishedsquarefeet12             -0.051075                    0.672593
# fips                             -0.043558                    0.064417
# fullbathcnt                       0.093458                    0.574096
# heatingorsystemtypeid            -0.042316                   -0.291480
# latitude                          0.004017                   -0.027756
# longitude                        -0.032388                    0.011174
# lotsizesquarefeet                -0.023714                    0.012100
# propertylandusetypeid            -0.458830                    0.059079
# rawcensustractandblock           -0.044166                    0.064843
# regionidcity                     -0.013087                   -0.015272
# regionidcounty                    0.043558                   -0.064417
# regionidzip                      -0.064279                    0.063965
# roomcnt                          -0.034781                   -0.123583
# unitcnt                           1.000000                   -0.004304
# structuretaxvaluedollarcnt       -0.004304                    1.000000
# taxvaluedollarcnt                 0.002865                    0.743668
# landtaxvaluedollarcnt             0.005884                    0.474987
# taxamount                         0.009986                    0.701126
# censustractandblock              -0.043912                    0.060107
# logerror                         -0.008679                    0.012175
# yeardifference                    0.106279                   -0.427937
# propertycountylandusecode_labels  0.041761                    0.038676
# propertyzoningdesc_labels        -0.011461                    0.008745
#
#                                   taxvaluedollarcnt  landtaxvaluedollarcnt  \
# parcelid                                   0.108378               0.131451
# bathroomcnt                                0.409102               0.239859
# bedroomcnt                                 0.228897               0.142587
# buildingqualitytypeid                     -0.055208               0.024085
# calculatedbathnbr                          0.416746               0.245013
# calculatedfinishedsquarefeet               0.507249               0.329372
# finishedsquarefeet12                       0.507636               0.328845
# fips                                       0.146449               0.159506
# fullbathcnt                                0.385969               0.218985
# heatingorsystemtypeid                     -0.175315              -0.084778
# latitude                                  -0.196797              -0.243788
# longitude                                  0.025089               0.026865
# lotsizesquarefeet                         -0.076301              -0.106996
# propertylandusetypeid                     -0.045769              -0.088475
# rawcensustractandblock                     0.144638               0.156924
# regionidcity                               0.013521               0.025387
# regionidcounty                            -0.146449              -0.159506
# regionidzip                               -0.007683              -0.042267
# roomcnt                                    0.024996               0.094461
# unitcnt                                    0.002865               0.005884
# structuretaxvaluedollarcnt                 0.743668               0.474987
# taxvaluedollarcnt                          1.000000               0.941257
# landtaxvaluedollarcnt                      0.941257               1.000000
# taxamount                                  0.909073               0.844180
# censustractandblock                        0.141087               0.154686
# logerror                                   0.007318               0.002598
# yeardifference                            -0.162588               0.002220
# propertycountylandusecode_labels           0.114851               0.131419
# propertyzoningdesc_labels                 -0.044206              -0.062375
#
#                                   taxamount  censustractandblock  logerror  \
# parcelid                           0.036577             0.870684  0.025329
# bathroomcnt                        0.387460             0.099102  0.045766
# bedroomcnt                         0.230341             0.067906  0.035055
# buildingqualitytypeid             -0.082563             0.417279 -0.007708
# calculatedbathnbr                  0.401416             0.103023  0.043166
# calculatedfinishedsquarefeet       0.502419             0.125288  0.050139
# finishedsquarefeet12               0.501731             0.131922  0.050546
# fips                               0.074968             0.994001  0.019448
# fullbathcnt                        0.379323            -0.010311  0.040571
# heatingorsystemtypeid             -0.140855            -0.295272 -0.013840
# latitude                          -0.119134            -0.674860 -0.019062
# longitude                         -0.034565             0.703416  0.022824
# lotsizesquarefeet                 -0.083357            -0.200515 -0.001955
# propertylandusetypeid             -0.071128             0.016865  0.002084
# rawcensustractandblock             0.073818             0.994221  0.019377
# regionidcity                       0.015491             0.058025  0.010770
# regionidcounty                    -0.074968            -0.994001 -0.019448
# regionidzip                       -0.042265             0.670147  0.016003
# roomcnt                           -0.029549             0.656379  0.015922
# unitcnt                            0.009986            -0.043912 -0.008679
# structuretaxvaluedollarcnt         0.701126             0.060107  0.012175
# taxvaluedollarcnt                  0.909073             0.141087  0.007318
# landtaxvaluedollarcnt              0.844180             0.154686  0.002598
# taxamount                          1.000000             0.068999 -0.023728
# censustractandblock                0.068999             1.000000  0.020006
# logerror                          -0.023728             0.020006  1.000000
# yeardifference                    -0.132536            -0.290499 -0.028347
# propertycountylandusecode_labels   0.033094             0.968873  0.015552
# propertyzoningdesc_labels         -0.016099            -0.306377 -0.013995
#
#                                   yeardifference  \
# parcelid                               -0.222907
# bathroomcnt                            -0.455964
# bedroomcnt                             -0.075797
# buildingqualitytypeid                   0.230517
# calculatedbathnbr                      -0.458126
# calculatedfinishedsquarefeet           -0.250244
# finishedsquarefeet12                   -0.265281
# fips                                   -0.289936
# fullbathcnt                            -0.405678
# heatingorsystemtypeid                   0.518832
# latitude                                0.037249
# longitude                              -0.229471
# lotsizesquarefeet                      -0.155921
# propertylandusetypeid                  -0.452982
# rawcensustractandblock                 -0.295039
# regionidcity                           -0.037166
# regionidcounty                          0.289936
# regionidzip                            -0.418668
# roomcnt                                 0.020642
# unitcnt                                 0.106279
# structuretaxvaluedollarcnt             -0.427937
# taxvaluedollarcnt                      -0.162588
# landtaxvaluedollarcnt                   0.002220
# taxamount                              -0.132536
# censustractandblock                    -0.290499
# logerror                               -0.028347
# yeardifference                          1.000000
# propertycountylandusecode_labels       -0.315118
# propertyzoningdesc_labels              -0.017828
#
#                                   propertycountylandusecode_labels  \
# parcelid                                                  0.852989
# bathroomcnt                                               0.093602
# bedroomcnt                                                0.006568
# buildingqualitytypeid                                     0.387709
# calculatedbathnbr                                         0.102588
# calculatedfinishedsquarefeet                              0.076094
# finishedsquarefeet12                                      0.070824
# fips                                                      0.971803
# fullbathcnt                                              -0.006417
# heatingorsystemtypeid                                    -0.326597
# latitude                                                 -0.670985
# longitude                                                 0.675103
# lotsizesquarefeet                                        -0.142743
# propertylandusetypeid                                     0.092383
# rawcensustractandblock                                    0.971456
# regionidcity                                              0.042128
# regionidcounty                                           -0.971803
# regionidzip                                               0.638416
# roomcnt                                                   0.623074
# unitcnt                                                   0.041761
# structuretaxvaluedollarcnt                                0.038676
# taxvaluedollarcnt                                         0.114851
# landtaxvaluedollarcnt                                     0.131419
# taxamount                                                 0.033094
# censustractandblock                                       0.968873
# logerror                                                  0.015552
# yeardifference                                           -0.315118
# propertycountylandusecode_labels                          1.000000
# propertyzoningdesc_labels                                -0.312320
#
#                                   propertyzoningdesc_labels
# parcelid                                          -0.212511
# bathroomcnt                                        0.018170
# bedroomcnt                                         0.042841
# buildingqualitytypeid                             -0.191120
# calculatedbathnbr                                  0.016810
# calculatedfinishedsquarefeet                      -0.000506
# finishedsquarefeet12                               0.000853
# fips                                              -0.316782
# fullbathcnt                                        0.053636
# heatingorsystemtypeid                              0.023738
# latitude                                           0.288372
# longitude                                         -0.127404
# lotsizesquarefeet                                  0.061937
# propertylandusetypeid                              0.016864
# rawcensustractandblock                            -0.307880
# regionidcity                                       0.190900
# regionidcounty                                     0.316782
# regionidzip                                       -0.093470
# roomcnt                                           -0.207093
# unitcnt                                           -0.011461
# structuretaxvaluedollarcnt                         0.008745
# taxvaluedollarcnt                                 -0.044206
# landtaxvaluedollarcnt                             -0.062375
# taxamount                                         -0.016099
# censustractandblock                               -0.306377
# logerror                                          -0.013995
# yeardifference                                    -0.017828
# propertycountylandusecode_labels                  -0.312320
# propertyzoningdesc_labels                          1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(no_out_df.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We observe high correlation among some of the feature variables from the above correlation plot. Hence we will drop some of the features and then build our model on top of that.

# %%
no_out_df.drop(columns=['calculatedbathnbr', 'calculatedfinishedsquarefeet', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'fullbathcnt'], axis=1, inplace=True)
plt.figure(figsize=(12,8))
sns.heatmap(no_out_df.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Re-Examining Dataset:

# %%
no_out_df.shape
# Out:
# (70260, 23)

# %%
no_out_df.head(10)
# Out:
#     parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 26  10726315          3.0         3.0                    4.0
# 27  10727091          2.0         3.0                    7.0
# 28  10730788          2.0         4.0                    7.0
# 29  10735394          3.0         4.0                    4.0
# 31  10743512          3.0         2.0                    4.0
# 32  10760933          2.0         4.0                    7.0
# 33  10772282          3.0         4.0                    4.0
# 34  10783331          2.0         3.0                    7.0
# 35  10784006          1.0         2.0                    7.0
# 36  10799070          2.0         2.0                    4.0
#
#     finishedsquarefeet12    fips  heatingorsystemtypeid   latitude  \
# 26                2445.0  6037.0                    2.0  34.184300
# 27                1160.0  6037.0                    2.0  34.188121
# 28                1570.0  6037.0                    2.0  34.188446
# 29                2863.0  6037.0                    2.0  34.171439
# 31                1394.0  6037.0                    2.0  34.152890
# 32                1212.0  6037.0                    7.0  34.220631
# 33                2597.0  6037.0                    2.0  34.209413
# 34                1742.0  6037.0                    7.0  34.185891
# 35                 950.0  6037.0                    7.0  34.192384
# 36                1001.0  6037.0                    2.0  34.178100
#
#      longitude  lotsizesquarefeet  propertylandusetypeid  \
# 26 -118.657000            63878.0                  266.0
# 27 -118.646361             7688.0                  261.0
# 28 -118.616724            11308.0                  261.0
# 29 -118.646883            16376.0                  261.0
# 31 -118.791494            77543.0                  269.0
# 32 -118.521001             7379.0                  261.0
# 33 -118.578052            10537.0                  261.0
# 34 -118.550426             7076.0                  261.0
# 35 -118.549670             6242.0                  261.0
# 36 -118.535000            87177.0                  266.0
#
#     rawcensustractandblock  regionidcity  regionidcounty  regionidzip  \
# 26               60.371352       12447.0          3101.0      96389.0
# 27               60.371352       12447.0          3101.0      96342.0
# 28               60.371351       12447.0          3101.0      96342.0
# 29               60.371373       12447.0          3101.0      96389.0
# 31               60.378003       34278.0          3101.0      96385.0
# 32               60.371313       12447.0          3101.0      96355.0
# 33               60.371341       12447.0          3101.0      96341.0
# 34               60.371331       12447.0          3101.0      96364.0
# 35               60.371325       12447.0          3101.0      96364.0
# 36               60.371393       12447.0          3101.0      96379.0
#
#     roomcnt  unitcnt  taxamount  censustractandblock  logerror  \
# 26      0.0      1.0    7170.22            60.371352    0.0383
# 27      0.0      1.0    5421.96            60.371352    0.0030
# 28      0.0      1.0    5097.78            60.371351   -0.0020
# 29      0.0      1.0    7475.21            60.371373    0.0129
# 31      0.0      1.0    5550.36            60.378003    0.0630
# 32      0.0      1.0    4560.02            60.371313   -0.1244
# 33      0.0      1.0    4998.86            60.371341    0.0545
# 34      0.0      1.0    5784.98            60.371331    0.0070
# 35      0.0      1.0    3441.90            60.371325    0.0611
# 36      0.0      1.0    3833.83            60.371393   -0.0471
#
#     yeardifference  propertycountylandusecode_labels  \
# 26            33.0                                 9
# 27            55.0                                 2
# 28            56.0                                 2
# 29            52.0                                 3
# 31            17.0                                10
# 32            61.0                                 2
# 33            51.0                                 2
# 34            62.0                                 2
# 35            64.0                                 2
# 36            36.0                                 9
#
#     propertyzoningdesc_labels
# 26                        627
# 27                        638
# 28                        638
# 29                        632
# 31                        769
# 32                        609
# 33                        638
# 34                        609
# 35                        609
# 36                        625

# %% [markdown]
# * Due to repetitive data, we will drop 1 of rawcensustractandblock and censustractandblock.
# * The propertycountylandusecode_labels will serve no useful purpose for our model prediction.
# * Hence we will drop those
# * parcelid filed will also server no use for prediction.
# * Hence we will drop those but after doing the train_test_split to keep the labels for predictions

# %%
no_out_df.drop(columns=['censustractandblock', 'propertycountylandusecode_labels'], axis=1, inplace=True)
no_out_df.shape
# Out:
# (70260, 21)

# %% [markdown]
# ### Saving Dataset:

# %%
no_out_df.to_csv('C:\Users\TRISHA\Documents\Data_science\House_Price_prediction_final\final_zillow_dataset.csv', index=False)

# %% [markdown]
# We have performed all the feature engineering steps necessary to ensure the dataset is ready to be fed to Machine Learning algorithms.
# Next we will perform a train test split of the data followed by feature scaling.
